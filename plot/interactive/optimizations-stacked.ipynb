# %%
# %matplotlib inline
import sys
sys.path.append('../../utils')
import utils as u
import math

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib.ticker import MultipleLocator
from random import randint
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib.backends.backend_pdf import PdfPages

from palettable.colorbrewer.sequential import YlGnBu_5

# %%
#Loading data

color=['#edf8b1','#7fcdbb','#225ea8']
df = pd.read_csv('../../data/stack_data.csv')

fig, ax = plt.subplots(figsize=(12, 5))
plt.xticks(rotation=90)

plt.xlim(-0.5, 16)
# Put limit on Y axis
plt.ylim(0, 1)


N = len(df['app'])
ind = np.arange(N)
width = 0.6


# Instantiating the X bar
# cbars = ax.bar(ind+0.8, df['mul'].values.tolist(), \
#                width, ecolor='k', color=u.getcolor(3), edgecolor='k');
#cbars = ax.bar(ind+0.8, df['data'].values.tolist(), width, color=YlGnBu_5.hex_colors[4])
cbars = ax.bar(ind+0.8, df['performance'].values.tolist(), width, color=color[2], edgecolor='k')

# ax.text(0, 0.9, "Banking + Fusion + Tile(4)", fontsize=18, rotation=0)


# Here is the label and arrow code of interest
fs = 14.0
ax.annotate('Banking, Fusion, Tile', xy=(0.13, 0.95), xytext=(0.13, 1.1), xycoords='axes fraction', 
            fontsize=fs*1.5, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white'),
            arrowprops=dict(arrowstyle='-[, widthB=3.2, lengthB=1.2', lw=2.0))

ax.annotate('Banking, Localization, Op-Fusion', xy=(0.63, 0.95), xytext=(0.63, 1.1), xycoords='axes fraction', 
            fontsize=fs*1.5, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white'),
            arrowprops=dict(arrowstyle='-[, widthB=11, lengthB=1.2', lw=2.0))



# Set X label values
ax.set_ylabel('Norm. Exe (ns)',fontsize=38, color='black')
ax.set_xticks(ind+0.8);

# Put the labels from 'app' coulmn
ax.set_xticklabels(u.rename(df['app']))
ax.set_facecolor('whitesmoke')

plt.grid(linestyle='--', which='major', color='darkgray')
plt.gca().xaxis.grid(False)
plt.gca().yaxis.grid(True, color='black')

plt.tick_params( axis='x', which='both', bottom=False, top=False, colors='black', labelsize=24)
plt.tick_params( axis='y', which='both', right=False, colors='black', labelsize=28 )
plt.tick_params(axis='both', which='major', direction='in', 
                length=6, width=3,color='black')

ax.set_axisbelow(True)
ax.spines['bottom'].set_color('gray')
ax.spines['top'].set_color('gray')
ax.spines['right'].set_color('gray')
ax.spines['left'].set_color('gray')

# Saving the plot
fig.savefig('stackOpt.pdf',
            facecolor=fig.get_facecolor(), bbox_inches='tight')
